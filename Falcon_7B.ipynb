# %% [markdown]
# <a href="https://colab.research.google.com/github/sushant-97/Chaabi_Assignment_CSV_Chat/blob/main/Falcon_7B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install transformers bitsandbytes accelerate -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 31.3 MB/s eta 0:00:00

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
import transformers
import torch

compute_dtype = getattr(torch, "float16")

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)

# %%
model_name = "tiiuae/falcon-7b"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    quantization_config=bnb_config,
    device_map="auto",
)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# configuration_falcon.py:   0%|          | 0.00/7.16k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b:
# - configuration_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.tiiuae.falcon-7b.898df1396f35e447d5fe44e0a3ccaaaa69f30d36.configuration_falcon:
# ...

# %%
prompt = "What are the main benefits of enrolling in a DataCamp career track?"
sequences = pipeline(
    prompt,
    max_length=100,
    do_sample=True,
    top_k=20,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result: What are the main benefits of enrolling in a DataCamp career track?
# The main benefits of joining a DataCamp career track are:
# - Get a certificate with the name of the career track and its content (e.g. Machine learning, Big Data) and a DataCamp badge
# - Learn at your own pace (DataCamp allows you to pause at any point)
# - Access to premium DataCamp content: DataCamp Pro lessons and projects
# - Access DataCamp's

# %%
sequences[0]['generated_text']
# Out:
# "What are the main benefits of enrolling in a DataCamp career track?\nThe main benefits of joining a DataCamp career track are:\n- Get a certificate with the name of the career track and its content (e.g. Machine learning, Big Data) and a DataCamp badge\n- Learn at your own pace (DataCamp allows you to pause at any point)\n- Access to premium DataCamp content: DataCamp Pro lessons and projects\n- Access DataCamp's"
